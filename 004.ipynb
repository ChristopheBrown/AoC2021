# %%
import re
import numpy as np

# %%
demo_data = '''7,4,9,5,11,17,23,2,0,14,21,24,10,16,13,6,15,25,12,22,18,20,8,19,3,26,1

22 13 17 11  0
 8  2 23  4 24
21  9 14 16  7
 6 10  3 18  5
 1 12 20 15 19

 3 15  0  2 22
 9 18 13 17  5
19  8  7 25 23
20 11 10 24  4
14 21 16 12  6

14 21 17 24  4
10 16 15  9 19
18  8 23 26 20
22 11 13  6  5
 2  0 12  3  7
 '''

with open("data/data-4.txt", "r", encoding="utf-8") as g:
    data = g.read()

# %%
def extract_ints_from_string(string):
    return [int(s) for s in string.split() if s.isdigit()]

def setup_callouts(data):
    end_of_callouts_idx = data[1:].index('\n') + 1
    callouts = data[:end_of_callouts_idx].strip('\n').split(',')
    return list(map(int, callouts))

class Board:

    def __init__(self, ID, num_layout, dims=(5,5), last_winner_flag=False):
        self.ID = ID+1
        self.dims = dims
        self.last_winner_flag=last_winner_flag
        self.setup_board(num_layout)
    
    def setup_board(self, num_layout):
        nums_int = extract_ints_from_string(num_layout)
        self.board = np.array(nums_int).reshape(self.dims)
        self.marks = np.zeros_like(self.board)
        
    def check_callout(self, callout):
        for row in range(self.board.shape[0]):
            for col in range(self.board.shape[1]):
                if self.board[col][row] == callout:
                    self.marks[col][row] = -1
         
        return self.check_victory(callout)
        
    def check_horizontals(self):
        for row in range(self.dims[0]):
            if all(x == -1 for x in self.marks[row]):
                return True
        return False

    def check_verticals(self):
        for col in range(self.dims[1]):
            if all(x == -1 for x in self.marks[:,col]):
                return True
        return False
    
    def check_victory(self, callout):
        if self.check_horizontals() or self.check_verticals():
            return self.confirm_victory(callout)
        return False
    
    def confirm_victory(self, callout):
        total = 0
        indices = np.argwhere(self.marks == 0)
        for coords in indices:
            total += self.board[coords[0]][coords[1]]
            
        print(f'Board #{self.ID} is completed with solution = {total * callout}.')
        if not self.last_winner_flag:
            self.show_board()
            self.show_marks()
        return self.ID
        
    def show_board(self):
        print(self.board)
        
    def show_marks(self):
        print(self.marks)

# %%
pattern = '\n(\d*\n.*\n.*\n.*\n.*\n.*)'
board_layouts = re.findall(pattern, demo_data)
boards = []

for layout_id in range(len(board_layouts)):
    boards.append(Board(ID=layout_id, num_layout=board_layouts[layout_id], last_winner_flag=True))
    
callouts = setup_callouts(demo_data)

winner_found = False
winners = []

for callout in callouts:
    if winner_found: # Use "break" to find the first winner, use "pass" to find the last winner
#         break
        pass
    print(f'Callout: {callout}')
    for board in boards:
        board_id = board.check_callout(callout)
        if board_id:
            winner_found = True
            if board_id not in winners:
                print(f'Adding #{board_id}')
                winners.append(board_id)
            
winners
# Out:
# Callout: 7
# Callout: 4
# Callout: 9
# Callout: 5
# Callout: 11
# Callout: 17
# Callout: 23
# Callout: 2
# Callout: 0
# Callout: 14
# Callout: 21
# Callout: 24
# Board #3 is completed with solution = 4512.
# Adding #3
# Callout: 10
# Board #3 is completed with solution = 1780.
# Callout: 16
# Board #1 is completed with solution = 2192.
# Adding #1
# Board #3 is completed with solution = 2592.
# Callout: 13
# Board #1 is completed with solution = 1612.
# Board #2 is completed with solution = 1924.
# Adding #2
# Board #3 is completed with solution = 1937.
# Callout: 6
# Board #1 is completed with solution = 708.
# Board #2 is completed with solution = 852.
# Board #3 is completed with solution = 858.
# Callout: 15
# Board #1 is completed with solution = 1545.
# Board #2 is completed with solution = 1905.
# Board #3 is completed with solution = 1920.
# Callout: 25
# Board #1 is completed with solution = 2575.
# Board #2 is completed with solution = 2550.
# Board #3 is completed with solution = 3200.
# Callout: 12
# Board #1 is completed with solution = 1092.
# Board #2 is completed with solution = 1080.
# Board #3 is completed with solution = 1392.
# Callout: 22
# Board #1 is completed with solution = 1518.
# Board #2 is completed with solution = 1496.
# Board #3 is completed with solution = 2068.
# Callout: 18
# Board #1 is completed with solution = 918.
# Board #2 is completed with solution = 900.
# Board #3 is completed with solution = 1368.
# Callout: 20
# Board #1 is completed with solution = 620.
# Board #2 is completed with solution = 600.
# Board #3 is completed with solution = 1120.
# Callout: 8
# Board #1 is completed with solution = 184.
# Board #2 is completed with solution = 176.
# Board #3 is completed with solution = 384.
# Callout: 19
# Board #1 is completed with solution = 76.
# Board #2 is completed with solution = 57.
# Board #3 is completed with solution = 551.
# Callout: 3
# Board #1 is completed with solution = 3.
# Board #2 is completed with solution = 0.
# Board #3 is completed with solution = 78.
# Callout: 26
# Board #1 is completed with solution = 26.
# Board #2 is completed with solution = 0.
# Board #3 is completed with solution = 0.
# Callout: 1
# Board #1 is completed with solution = 0.
# Board #2 is completed with solution = 0.
# Board #3 is completed with solution = 0.
# [3, 1, 2]

# %%
pattern = '\n(\d*\n.*\n.*\n.*\n.*\n.*)'
board_layouts = re.findall(pattern, data)
boards = []

for layout_id in range(len(board_layouts)):
    boards.append(Board(ID=layout_id, num_layout=board_layouts[layout_id], last_winner_flag=True))
    
callouts = setup_callouts(data)

winner_found = False
winners = []

for callout in callouts:
    if winner_found: # Use "break" to find the first winner, use "pass" to find the last winner
#         break
        pass
    print(f'Callout: {callout}')
    for board in boards:
        board_id = board.check_callout(callout)
        if board_id:
            winner_found = True
            if board_id not in winners:
                winners.append(board_id)
# Out:
# Callout: 87
# Callout: 12
# Callout: 53
# Callout: 23
# Callout: 31
# Callout: 70
# Callout: 37
# Callout: 79
# Callout: 95
# Callout: 16
# Callout: 72
# Callout: 9
# Callout: 98
# Callout: 92
# Callout: 5
# Callout: 74
# Callout: 17
# Callout: 60
# Callout: 96
# Callout: 80
# Callout: 75
# Callout: 11
# Callout: 73
# Callout: 33
# Callout: 3
# Board #14 is completed with solution = 2745.
# Callout: 84
# Board #14 is completed with solution = 76860.
# Callout: 81
# Board #14 is completed with solution = 67554.
# Callout: 2
# Board #14 is completed with solution = 1664.
# Callout: 97
# Board #14 is completed with solution = 80704.
# Callout: 93
# Board #14 is completed with solution = 68727.
# Callout: 59
# Board #14 is completed with solution = 43601.
# Board #46 is completed with solution = 33040.
# Callout: 13
# Board #14 is completed with solution = 9607.
# Board #21 is completed with solution = 9867.
# Board #46 is completed with solution = 7280.
# Callout: 77
# Board #14 is completed with solution = 56903.
# Board #21 is completed with solution = 52514.
# Board #46 is completed with solution = 43120.
# Callout: 52
# Board #14 is completed with solution = 38428.
# Board #21 is completed with solution = 32760.
# Board #46 is completed with solution = 29120.
# Callout: 69
# Board #14 is completed with solution = 50991.
# Board #21 is completed with solution = 43470.
# Board #46 is completed with solution = 38640.
# Board #54 is completed with solution = 42849.
# Callout: 83
# Board #7 is completed with solution = 44986.
# Board #9 is completed with solution = 33698.
# Board #14 is completed with solution = 61337.
# Board #21 is completed with solution = 52290.
# Board #46 is completed with solution = 46480.
# Board #54 is completed with solution = 51543.
# Callout: 51
# Board #7 is completed with solution = 27642.
# Board #9 is completed with solution = 20706.
# Board #14 is completed with solution = 35088.
# Board #21 is completed with solution = 32130.
# Board #30 is completed with solution = 29478.
# Board #46 is completed with solution = 25959.
# Board #54 is completed with solution = 31671.
# Callout: 64
# Board #7 is completed with solution = 34688.
# Board #9 is completed with solution = 25984.
# Board #14 is completed with solution = 44032.
# Board #15 is completed with solution = 38400.
# Board #21 is completed with solution = 40320.
# Board #30 is completed with solution = 32896.
# Board #46 is completed with solution = 32576.
# Board #54 is completed with solution = 39744.
# Board #76 is completed with solution = 38336.
# Board #92 is completed with solution = 26880.
# Callout: 48
# Board #7 is completed with solution = 26016.
# Board #9 is completed with solution = 17184.
# Board #14 is completed with solution = 30720.
# Board #15 is completed with solution = 26496.
# Board #21 is completed with solution = 30240.
# Board #30 is completed with solution = 24672.
# Board #46 is completed with solution = 24432.
# Board #54 is completed with solution = 29808.
# Board #76 is completed with solution = 28752.
# Board #92 is completed with solution = 20160.
# Callout: 82
# Board #7 is completed with solution = 44444.
# Board #9 is completed with solution = 22632.
# Board #14 is completed with solution = 52480.
# Board #15 is completed with solution = 45264.
# Board #21 is completed with solution = 44936.
# Board #30 is completed with solution = 42148.
# Board #46 is completed with solution = 35014.
# Board #54 is completed with solution = 44198.
# Board #73 is completed with solution = 42476.
# Board #76 is completed with solution = 49118.
# Board #92 is completed with solution = 34440.
# Callout: 7
# Board #7 is completed with solution = 3794.
# Board #9 is completed with solution = 1883.
# Board #14 is completed with solution = 4480.
# Board #15 is completed with solution = 3864.
# Board #21 is completed with solution = 3836.
# Board #30 is completed with solution = 3598.
# Board #46 is completed with solution = 2989.
# Board #54 is completed with solution = 3773.
# Board #73 is completed with solution = 3577.
# Board #76 is completed with solution = 4193.
# Board #92 is completed with solution = 2940.
# Callout: 49
# Board #7 is completed with solution = 26558.
# Board #9 is completed with solution = 13181.
# Board #14 is completed with solution = 31360.
# Board #15 is completed with solution = 27048.
# Board #21 is completed with solution = 26852.
# Board #22 is completed with solution = 22246.
# Board #30 is completed with solution = 25186.
# Board #46 is completed with solution = 20923.
# Board #54 is completed with solution = 24010.
# Board #73 is completed with solution = 25039.
# Board #76 is completed with solution = 29351.
# Board #92 is completed with solution = 20580.
# Callout: 20
# Board #7 is completed with solution = 10840.
# Board #9 is completed with solution = 5380.
# Board #14 is completed with solution = 12800.
# Board #15 is completed with solution = 11040.
# Board #21 is completed with solution = 10960.
# Board #22 is completed with solution = 8680.
# Board #30 is completed with solution = 10280.
# Board #46 is completed with solution = 8540.
# Board #54 is completed with solution = 9800.
# Board #73 is completed with solution = 10220.
# Board #76 is completed with solution = 11580.
# Board #92 is completed with solution = 8400.
# Callout: 8
# Board #7 is completed with solution = 4336.
# Board #9 is completed with solution = 2152.
# Board #14 is completed with solution = 5120.
# Board #15 is completed with solution = 4416.
# Board #21 is completed with solution = 4384.
# Board #22 is completed with solution = 3472.
# Board #27 is completed with solution = 5904.
# Board #30 is completed with solution = 4048.
# Board #46 is completed with solution = 3416.
# Board #51 is completed with solution = 4688.
# Board #54 is completed with solution = 3920.
# Board #73 is completed with solution = 4088.
# Board #76 is completed with solution = 4568.
# Board #89 is completed with solution = 5272.
# Board #92 is completed with solution = 3360.
# Callout: 36
# Board #7 is completed with solution = 19512.
# Board #9 is completed with solution = 9684.
# Board #12 is completed with solution = 21564.
# Board #14 is completed with solution = 23040.
# Board #15 is completed with solution = 18576.
# Board #21 is completed with solution = 19728.
# Board #22 is completed with solution = 15624.
# Board #27 is completed with solution = 26568.
# Board #30 is completed with solution = 18216.
# Board #46 is completed with solution = 15372.
# Board #51 is completed with solution = 19800.
# Board #54 is completed with solution = 16344.
# Board #60 is completed with solution = 15804.
# Board #73 is completed with solution = 18396.
# Board #76 is completed with solution = 19260.
# Board #86 is completed with solution = 17784.
# Board #89 is completed with solution = 23724.
# Board #92 is completed with solution = 15120.
# Callout: 66
# Board #7 is completed with solution = 31416.
# Board #9 is completed with solution = 17754.
# Board #12 is completed with solution = 39534.
# Board #14 is completed with solution = 42240.
# Board #15 is completed with solution = 29700.
# Board #21 is completed with solution = 31812.
# Board #22 is completed with solution = 28644.
# Board #27 is completed with solution = 48708.
# Board #30 is completed with solution = 33396.
# Board #32 is completed with solution = 31614.
# Board #33 is completed with solution = 38874.
# Board #46 is completed with solution = 28182.
# Board #51 is completed with solution = 36300.
# Board #54 is completed with solution = 29964.
# Board #60 is completed with solution = 28974.
# Board #73 is completed with solution = 33726.
# Board #76 is completed with solution = 35310.
# Board #86 is completed with solution = 32604.
# Board #89 is completed with solution = 43494.
# Board #92 is completed with solution = 27720.
# Board #100 is completed with solution = 47322.
# Callout: 19
# Board #7 is completed with solution = 9044.
# Board #9 is completed with solution = 5111.
# Board #12 is completed with solution = 11381.
# Board #14 is completed with solution = 12160.
# Board #15 is completed with solution = 8550.
# Board #21 is completed with solution = 9158.
# Board #22 is completed with solution = 7885.
# Board #27 is completed with solution = 14022.
# Board #30 is completed with solution = 9614.
# Board #32 is completed with solution = 9101.
# Board #33 is completed with solution = 11191.
# Board #43 is completed with solution = 13281.
# Board #46 is completed with solution = 8113.
# Board #51 is completed with solution = 10450.
# Board #54 is completed with solution = 8626.
# Board #60 is completed with solution = 8341.
# Board #73 is completed with solution = 9709.
# Board #76 is completed with solution = 10165.
# Board #83 is completed with solution = 9462.
# Board #86 is completed with solution = 9386.
# Board #89 is completed with solution = 12521.
# Board #92 is completed with solution = 7980.
# Board #100 is completed with solution = 13623.
# Callout: 0
# Board #7 is completed with solution = 0.
# Board #9 is completed with solution = 0.
# Board #12 is completed with solution = 0.
# Board #14 is completed with solution = 0.
# Board #15 is completed with solution = 0.
# Board #21 is completed with solution = 0.
# Board #22 is completed with solution = 0.
# Board #23 is completed with solution = 0.
# Board #27 is completed with solution = 0.
# Board #30 is completed with solution = 0.
# Board #32 is completed with solution = 0.
# Board #33 is completed with solution = 0.
# Board #43 is completed with solution = 0.
# Board #46 is completed with solution = 0.
# Board #51 is completed with solution = 0.
# Board #54 is completed with solution = 0.
# Board #60 is completed with solution = 0.
# Board #73 is completed with solution = 0.
# Board #76 is completed with solution = 0.
# Board #82 is completed with solution = 0.
# Board #83 is completed with solution = 0.
# Board #86 is completed with solution = 0.
# Board #88 is completed with solution = 0.
# Board #89 is completed with solution = 0.
# Board #92 is completed with solution = 0.
# Board #100 is completed with solution = 0.
# Callout: 99
# Board #7 is completed with solution = 47124.
# Board #9 is completed with solution = 26631.
# Board #12 is completed with solution = 59301.
# Board #14 is completed with solution = 53559.
# Board #15 is completed with solution = 44550.
# Board #21 is completed with solution = 37917.
# Board #22 is completed with solution = 31284.
# Board #23 is completed with solution = 32076.
# Board #27 is completed with solution = 73062.
# Board #30 is completed with solution = 50094.
# Board #32 is completed with solution = 47421.
# Board #33 is completed with solution = 58311.
# Board #43 is completed with solution = 69201.
# Board #46 is completed with solution = 42273.
# Board #48 is completed with solution = 50490.
# Board #51 is completed with solution = 54450.
# Board #54 is completed with solution = 44946.
# Board #60 is completed with solution = 43461.
# Board #73 is completed with solution = 50589.
# Board #76 is completed with solution = 52965.
# Board #82 is completed with solution = 70587.
# Board #83 is completed with solution = 49302.
# Board #86 is completed with solution = 48906.
# Board #88 is completed with solution = 44055.
# Board #89 is completed with solution = 55440.
# Board #92 is completed with solution = 31779.
# Board #100 is completed with solution = 61182.
# Callout: 41
# Board #7 is completed with solution = 19516.
# Board #9 is completed with solution = 11029.
# Board #12 is completed with solution = 24559.
# Board #14 is completed with solution = 20500.
# Board #15 is completed with solution = 16769.
# Board #21 is completed with solution = 15703.
# Board #22 is completed with solution = 12956.
# Board #23 is completed with solution = 13284.
# Board #27 is completed with solution = 30258.
# Board #30 is completed with solution = 20746.
# Board #32 is completed with solution = 19639.
# Board #33 is completed with solution = 24149.
# Board #43 is completed with solution = 28659.
# Board #46 is completed with solution = 17507.
# Board #48 is completed with solution = 20910.
# Board #51 is completed with solution = 22550.
# Board #54 is completed with solution = 18614.
# Board #60 is completed with solution = 17999.
# Board #61 is completed with solution = 23206.
# Board #70 is completed with solution = 15416.
# Board #73 is completed with solution = 20951.
# Board #76 is completed with solution = 20254.
# Board #82 is completed with solution = 29233.
# Board #83 is completed with solution = 20418.
# Board #86 is completed with solution = 20254.
# Board #88 is completed with solution = 16564.
# Board #89 is completed with solution = 22960.
# Board #92 is completed with solution = 13161.
# Board #100 is completed with solution = 23657.
# Callout: 91
# Board #7 is completed with solution = 43316.
# Board #9 is completed with solution = 24479.
# Board #12 is completed with solution = 54509.
# Board #14 is completed with solution = 45500.
# Board #15 is completed with solution = 37219.
# Board #21 is completed with solution = 34853.
# Board #22 is completed with solution = 28756.
# Board #23 is completed with solution = 29484.
# Board #27 is completed with solution = 58877.
# Board #30 is completed with solution = 46046.
# Board #32 is completed with solution = 43589.
# Board #33 is completed with solution = 53599.
# Board #34 is completed with solution = 58331.
# Board #43 is completed with solution = 63609.
# Board #46 is completed with solution = 38857.
# Board #48 is completed with solution = 46410.
# Board #51 is completed with solution = 50050.
# Board #54 is completed with solution = 41314.
# Board #55 is completed with solution = 28665.
# Board #60 is completed with solution = 39949.
# Board #61 is completed with solution = 51506.
# Board #70 is completed with solution = 34216.
# Board #73 is completed with solution = 46501.
# Board #76 is completed with solution = 36673.
# Board #82 is completed with solution = 64883.
# Board #83 is completed with solution = 45318.
# Board #86 is completed with solution = 44954.
# Board #88 is completed with solution = 36764.
# Board #89 is completed with solution = 42679.
# Board #92 is completed with solution = 29211.
# Board #100 is completed with solution = 52507.
# Callout: 78
# Board #7 is completed with solution = 31044.
# Board #9 is completed with solution = 20982.
# Board #11 is completed with solution = 39936.
# Board #12 is completed with solution = 40638.
# Board #14 is completed with solution = 32916.
# Board #15 is completed with solution = 31902.
# Board #21 is completed with solution = 29874.
# Board #22 is completed with solution = 24648.
# Board #23 is completed with solution = 25272.
# Board #25 is completed with solution = 25740.
# Board #27 is completed with solution = 50466.
# Board #30 is completed with solution = 39468.
# Board #32 is completed with solution = 37362.
# Board #33 is completed with solution = 45942.
# Board #34 is completed with solution = 49998.
# Board #43 is completed with solution = 54522.
# Board #46 is completed with solution = 33306.
# Board #48 is completed with solution = 33696.
# Board #51 is completed with solution = 42900.
# Board #54 is completed with solution = 35412.
# Board #55 is completed with solution = 24570.
# Board #60 is completed with solution = 34242.
# Board #61 is completed with solution = 38064.
# Board #70 is completed with solution = 29328.
# Board #73 is completed with solution = 39858.
# Board #76 is completed with solution = 31434.
# Board #82 is completed with solution = 55614.
# Board #83 is completed with solution = 32760.
# Board #86 is completed with solution = 38532.
# Board #87 is completed with solution = 40560.
# Board #88 is completed with solution = 25428.
# Board #89 is completed with solution = 36582.
# Board #92 is completed with solution = 25038.
# Board #93 is completed with solution = 46956.
# Board #100 is completed with solution = 45006.
# Callout: 42
# Board #7 is completed with solution = 16716.
# Board #9 is completed with solution = 9534.
# Board #11 is completed with solution = 19740.
# Board #12 is completed with solution = 21882.
# Board #14 is completed with solution = 17724.
# Board #15 is completed with solution = 17178.
# Board #21 is completed with solution = 16086.
# Board #22 is completed with solution = 13272.
# Board #23 is completed with solution = 13608.
# Board #25 is completed with solution = 12096.
# Board #27 is completed with solution = 27174.
# Board #30 is completed with solution = 21252.
# Board #32 is completed with solution = 18354.
# Board #33 is completed with solution = 24738.
# Board #34 is completed with solution = 26922.
# Board #43 is completed with solution = 29358.
# Board #46 is completed with solution = 16170.
# Board #48 is completed with solution = 18144.
# Board #51 is completed with solution = 23100.
# Board #54 is completed with solution = 19068.
# Board #55 is completed with solution = 13230.
# Board #60 is completed with solution = 18438.
# Board #61 is completed with solution = 18732.
# Board #70 is completed with solution = 14028.
# Board #73 is completed with solution = 19698.
# Board #76 is completed with solution = 15162.
# Board #82 is completed with solution = 29946.
# Board #83 is completed with solution = 17640.
# Board #86 is completed with solution = 20748.
# Board #87 is completed with solution = 21840.
# Board #88 is completed with solution = 13692.
# Board #89 is completed with solution = 19698.
# Board #92 is completed with solution = 13482.
# Board #93 is completed with solution = 25284.
# Board #100 is completed with solution = 22470.
# Callout: 40
# Board #4 is completed with solution = 15720.
# Board #7 is completed with solution = 15920.
# Board #9 is completed with solution = 9080.
# Board #11 is completed with solution = 17200.
# Board #12 is completed with solution = 20840.
# Board #14 is completed with solution = 16880.
# Board #15 is completed with solution = 16360.
# Board #21 is completed with solution = 15320.
# Board #22 is completed with solution = 11040.
# Board #23 is completed with solution = 12960.
# Board #25 is completed with solution = 11520.
# Board #27 is completed with solution = 25880.
# Board #30 is completed with solution = 18640.
# Board #32 is completed with solution = 17480.
# Board #33 is completed with solution = 23560.
# Board #34 is completed with solution = 25640.
# Board #43 is completed with solution = 27960.
# Board #46 is completed with solution = 15400.
# Board #48 is completed with solution = 17280.
# Board #51 is completed with solution = 22000.
# Board #54 is completed with solution = 18160.
# Board #55 is completed with solution = 12600.
# Board #60 is completed with solution = 17560.
# Board #61 is completed with solution = 17840.
# Board #70 is completed with solution = 13360.
# Board #73 is completed with solution = 18760.
# Board #76 is completed with solution = 14440.
# Board #82 is completed with solution = 26920.
# Board #83 is completed with solution = 16800.
# Board #86 is completed with solution = 19760.
# Board #87 is completed with solution = 20800.
# Board #88 is completed with solution = 13040.
# Board #89 is completed with solution = 18760.
# Board #92 is completed with solution = 12840.
# Board #93 is completed with solution = 24080.
# Board #100 is completed with solution = 21400.
# Callout: 62
# Board #4 is completed with solution = 20522.
# Board #7 is completed with solution = 24676.
# Board #9 is completed with solution = 10230.
# Board #11 is completed with solution = 26660.
# Board #12 is completed with solution = 32302.
# Board #14 is completed with solution = 26164.
# Board #15 is completed with solution = 25358.
# Board #21 is completed with solution = 23746.
# Board #22 is completed with solution = 17112.
# Board #23 is completed with solution = 16244.
# Board #25 is completed with solution = 17856.
# Board #27 is completed with solution = 36270.
# Board #30 is completed with solution = 25048.
# Board #32 is completed with solution = 23250.
# Board #33 is completed with solution = 36518.
# Board #34 is completed with solution = 39742.
# Board #43 is completed with solution = 43338.
# Board #46 is completed with solution = 23870.
# Board #48 is completed with solution = 26784.
# Board #51 is completed with solution = 30256.
# Board #54 is completed with solution = 28148.
# Board #55 is completed with solution = 19530.
# Board #57 is completed with solution = 27466.
# Board #60 is completed with solution = 27218.
# Board #61 is completed with solution = 27652.
# Board #70 is completed with solution = 20708.
# Board #73 is completed with solution = 29078.
# Board #76 is completed with solution = 22382.
# Board #82 is completed with solution = 41726.
# Board #83 is completed with solution = 26040.
# Board #86 is completed with solution = 30628.
# Board #87 is completed with solution = 32240.
# Board #88 is completed with solution = 20212.
# Board #89 is completed with solution = 25234.
# Board #92 is completed with solution = 16058.
# Board #93 is completed with solution = 37324.
# Board #100 is completed with solution = 33170.
# Callout: 63
# Board #4 is completed with solution = 16884.
# Board #7 is completed with solution = 21105.
# Board #9 is completed with solution = 10395.
# Board #11 is completed with solution = 27090.
# Board #12 is completed with solution = 32823.
# Board #14 is completed with solution = 26586.
# Board #15 is completed with solution = 25767.
# Board #21 is completed with solution = 24129.
# Board #22 is completed with solution = 17388.
# Board #23 is completed with solution = 16506.
# Board #25 is completed with solution = 18144.
# Board #27 is completed with solution = 36855.
# Board #30 is completed with solution = 25452.
# Board #32 is completed with solution = 23625.
# Board #33 is completed with solution = 33138.
# Board #34 is completed with solution = 40383.
# Board #43 is completed with solution = 44037.
# Board #46 is completed with solution = 24255.
# Board #48 is completed with solution = 23247.
# Board #51 is completed with solution = 26775.
# Board #52 is completed with solution = 29106.
# Board #54 is completed with solution = 28602.
# Board #55 is completed with solution = 19845.
# Board #57 is completed with solution = 27909.
# Board #60 is completed with solution = 27657.
# Board #61 is completed with solution = 28098.
# Board #70 is completed with solution = 21042.
# Board #73 is completed with solution = 29547.
# Board #76 is completed with solution = 18774.
# Board #82 is completed with solution = 38430.
# Board #83 is completed with solution = 26460.
# Board #86 is completed with solution = 31122.
# Board #87 is completed with solution = 32760.
# Board #88 is completed with solution = 20538.
# Board #89 is completed with solution = 25641.
# Board #92 is completed with solution = 16317.
# Board #93 is completed with solution = 37926.
# Board #100 is completed with solution = 33705.
# Callout: 57
# Board #4 is completed with solution = 15276.
# Board #7 is completed with solution = 15846.
# Board #9 is completed with solution = 9405.
# Board #11 is completed with solution = 24510.
# Board #12 is completed with solution = 26448.
# Board #14 is completed with solution = 20805.
# Board #15 is completed with solution = 23313.
# Board #21 is completed with solution = 21831.
# Board #22 is completed with solution = 15732.
# Board #23 is completed with solution = 14934.
# Board #25 is completed with solution = 16416.
# Board #27 is completed with solution = 30096.
# Board #30 is completed with solution = 23028.
# Board #32 is completed with solution = 21375.
# Board #33 is completed with solution = 26733.
# Board #34 is completed with solution = 36537.
# Board #43 is completed with solution = 39843.
# Board #46 is completed with solution = 21945.
# Board #48 is completed with solution = 17784.
# Board #51 is completed with solution = 24225.
# Board #52 is completed with solution = 26334.
# Board #54 is completed with solution = 25878.
# Board #55 is completed with solution = 14706.
# Board #57 is completed with solution = 25251.
# Board #60 is completed with solution = 25023.
# Board #61 is completed with solution = 25422.
# Board #68 is completed with solution = 27816.
# Board #70 is completed with solution = 19038.
# Board #73 is completed with solution = 26733.
# Board #76 is completed with solution = 16986.
# Board #82 is completed with solution = 31521.
# Board #83 is completed with solution = 23940.
# Board #86 is completed with solution = 28158.
# Board #87 is completed with solution = 29640.
# Board #88 is completed with solution = 18582.
# Board #89 is completed with solution = 23199.
# Board #92 is completed with solution = 14763.
# Board #93 is completed with solution = 34314.
# Board #100 is completed with solution = 30495.
# Callout: 39
# Board #4 is completed with solution = 10452.
# Board #7 is completed with solution = 10842.
# Board #9 is completed with solution = 6435.
# Board #11 is completed with solution = 16770.
# Board #12 is completed with solution = 18096.
# Board #14 is completed with solution = 14235.
# Board #15 is completed with solution = 15951.
# Board #21 is completed with solution = 14937.
# Board #22 is completed with solution = 10764.
# Board #23 is completed with solution = 10218.
# Board #25 is completed with solution = 11232.
# Board #27 is completed with solution = 20592.
# Board #30 is completed with solution = 15756.
# Board #32 is completed with solution = 14625.
# Board #33 is completed with solution = 18291.
# Board #34 is completed with solution = 24999.
# Board #36 is completed with solution = 17238.
# Board #43 is completed with solution = 27261.
# Board #46 is completed with solution = 15015.
# Board #48 is completed with solution = 10647.
# Board #51 is completed with solution = 16575.
# Board #52 is completed with solution = 18018.
# Board #54 is completed with solution = 17706.
# Board #55 is completed with solution = 10062.
# Board #57 is completed with solution = 17277.
# Board #59 is completed with solution = 15093.
# Board #60 is completed with solution = 17121.
# Board #61 is completed with solution = 17394.
# Board #68 is completed with solution = 19032.
# Board #70 is completed with solution = 13026.
# Board #73 is completed with solution = 18291.
# Board #76 is completed with solution = 11622.
# Board #82 is completed with solution = 21567.
# Board #83 is completed with solution = 16380.
# Board #84 is completed with solution = 13494.
# Board #86 is completed with solution = 19266.
# Board #87 is completed with solution = 18759.
# Board #88 is completed with solution = 12714.
# Board #89 is completed with solution = 14352.
# Board #92 is completed with solution = 8580.
# Board #93 is completed with solution = 23478.
# Board #100 is completed with solution = 20865.
# Callout: 55
# Board #4 is completed with solution = 14740.
# Board #7 is completed with solution = 15290.
# Board #9 is completed with solution = 9075.
# Board #11 is completed with solution = 20625.
# Board #12 is completed with solution = 22495.
# Board #13 is completed with solution = 22715.
# Board #14 is completed with solution = 20075.
# Board #15 is completed with solution = 22495.
# Board #21 is completed with solution = 21065.
# Board #22 is completed with solution = 15180.
# Board #23 is completed with solution = 14410.
# Board #24 is completed with solution = 27885.
# Board #25 is completed with solution = 15840.
# Board #27 is completed with solution = 26015.
# Board #30 is completed with solution = 22220.
# Board #32 is completed with solution = 17600.
# Board #33 is completed with solution = 25795.
# Board #34 is completed with solution = 35255.
# Board #36 is completed with solution = 21285.
# Board #43 is completed with solution = 35420.
# Board #46 is completed with solution = 18150.
# Board #48 is completed with solution = 15015.
# Board #51 is completed with solution = 23375.
# Board #52 is completed with solution = 25410.
# Board #54 is completed with solution = 24970.
# Board #55 is completed with solution = 11165.
# Board #57 is completed with solution = 21340.
# Board #59 is completed with solution = 21285.
# Board #60 is completed with solution = 24145.
# Board #61 is completed with solution = 21505.
# Board #62 is completed with solution = 15070.
# Board #68 is completed with solution = 23815.
# Board #70 is completed with solution = 18370.
# Board #73 is completed with solution = 25795.
# Board #76 is completed with solution = 16390.
# Board #82 is completed with solution = 27390.
# Board #83 is completed with solution = 23100.
# Board #84 is completed with solution = 19030.
# Board #86 is completed with solution = 27170.
# Board #87 is completed with solution = 26455.
# Board #88 is completed with solution = 17930.
# Board #89 is completed with solution = 17215.
# Board #92 is completed with solution = 9075.
# Board #93 is completed with solution = 33110.
# Board #98 is completed with solution = 25080.
# Board #100 is completed with solution = 29425.
# Callout: 47
# Board #4 is completed with solution = 12596.
# Board #7 is completed with solution = 13066.
# Board #9 is completed with solution = 7755.
# Board #11 is completed with solution = 15416.
# Board #12 is completed with solution = 17014.
# Board #13 is completed with solution = 17202.
# Board #14 is completed with solution = 17155.
# Board #15 is completed with solution = 17014.
# Board #21 is completed with solution = 18001.
# Board #22 is completed with solution = 12972.
# Board #23 is completed with solution = 12314.
# Board #24 is completed with solution = 21620.
# Board #25 is completed with solution = 11327.
# Board #27 is completed with solution = 22231.
# Board #28 is completed with solution = 25756.
# Board #30 is completed with solution = 18988.
# Board #32 is completed with solution = 15040.
# Board #33 is completed with solution = 22043.
# Board #34 is completed with solution = 30127.
# Board #36 is completed with solution = 18189.
# Board #43 is completed with solution = 30268.
# Board #46 is completed with solution = 15510.
# Board #48 is completed with solution = 12831.
# Board #51 is completed with solution = 17766.
# Board #52 is completed with solution = 19505.
# Board #54 is completed with solution = 21338.
# Board #55 is completed with solution = 9541.
# Board #57 is completed with solution = 18236.
# Board #59 is completed with solution = 18189.
# Board #60 is completed with solution = 20633.
# Board #61 is completed with solution = 18377.
# Board #62 is completed with solution = 12878.
# Board #68 is completed with solution = 20351.
# Board #70 is completed with solution = 15698.
# Board #73 is completed with solution = 22043.
# Board #76 is completed with solution = 14006.
# Board #82 is completed with solution = 21197.
# Board #83 is completed with solution = 19740.
# Board #84 is completed with solution = 16262.
# Board #86 is completed with solution = 23218.
# Board #87 is completed with solution = 22607.
# Board #88 is completed with solution = 15322.
# Board #89 is completed with solution = 14711.
# Board #92 is completed with solution = 7755.
# Board #93 is completed with solution = 28294.
# Board #98 is completed with solution = 21432.
# Board #100 is completed with solution = 25145.
# Callout: 29
# Board #1 is completed with solution = 10933.
# Board #4 is completed with solution = 7772.
# Board #6 is completed with solution = 12644.
# Board #7 is completed with solution = 7221.
# Board #9 is completed with solution = 4785.
# Board #11 is completed with solution = 8671.
# Board #12 is completed with solution = 10498.
# Board #13 is completed with solution = 10614.
# Board #14 is completed with solution = 10585.
# Board #15 is completed with solution = 10498.
# Board #21 is completed with solution = 11107.
# Board #22 is completed with solution = 8004.
# Board #23 is completed with solution = 7598.
# Board #24 is completed with solution = 13340.
# Board #25 is completed with solution = 6148.
# Board #27 is completed with solution = 12876.
# Board #28 is completed with solution = 15892.
# Board #30 is completed with solution = 11716.
# Board #32 is completed with solution = 9280.
# Board #33 is completed with solution = 13601.
# Board #34 is completed with solution = 18589.
# Board #36 is completed with solution = 11223.
# Board #43 is completed with solution = 18676.
# Board #46 is completed with solution = 9570.
# Board #48 is completed with solution = 7076.
# Board #50 is completed with solution = 14268.
# Board #51 is completed with solution = 10962.
# Board #52 is completed with solution = 12035.
# Board #54 is completed with solution = 13166.
# Board #55 is completed with solution = 5887.
# Board #57 is completed with solution = 11252.
# Board #59 is completed with solution = 11223.
# Board #60 is completed with solution = 11890.
# Board #61 is completed with solution = 10498.
# Board #62 is completed with solution = 7946.
# Board #64 is completed with solution = 14094.
# Board #68 is completed with solution = 11716.
# Board #70 is completed with solution = 8845.
# Board #73 is completed with solution = 13601.
# Board #76 is completed with solution = 8642.
# Board #82 is completed with solution = 13079.
# Board #83 is completed with solution = 12180.
# Board #84 is completed with solution = 10034.
# Board #86 is completed with solution = 14326.
# Board #87 is completed with solution = 13949.
# Board #88 is completed with solution = 8613.
# Board #89 is completed with solution = 8236.
# Board #92 is completed with solution = 4785.
# Board #93 is completed with solution = 17458.
# Board #98 is completed with solution = 13224.
# Board #100 is completed with solution = 14674.
# Callout: 50
# Board #1 is completed with solution = 18850.
# Board #4 is completed with solution = 10900.
# Board #6 is completed with solution = 21800.
# Board #7 is completed with solution = 12450.
# Board #9 is completed with solution = 8250.
# Board #11 is completed with solution = 12450.
# Board #12 is completed with solution = 18100.
# Board #13 is completed with solution = 18300.
# Board #14 is completed with solution = 18250.
# Board #15 is completed with solution = 18100.
# Board #21 is completed with solution = 19150.
# Board #22 is completed with solution = 13800.
# Board #23 is completed with solution = 13100.
# Board #24 is completed with solution = 23000.
# Board #25 is completed with solution = 10600.
# Board #27 is completed with solution = 22200.
# Board #28 is completed with solution = 27400.
# Board #30 is completed with solution = 20200.
# Board #31 is completed with solution = 25450.
# Board #32 is completed with solution = 16000.
# Board #33 is completed with solution = 20950.
# Board #34 is completed with solution = 32050.
# Board #36 is completed with solution = 19350.
# Board #43 is completed with solution = 32200.
# Board #46 is completed with solution = 16500.
# Board #48 is completed with solution = 9700.
# Board #50 is completed with solution = 24600.
# Board #51 is completed with solution = 18900.
# Board #52 is completed with solution = 20750.
# Board #54 is completed with solution = 22700.
# Board #55 is completed with solution = 10150.
# Board #57 is completed with solution = 19400.
# Board #59 is completed with solution = 19350.
# Board #60 is completed with solution = 20500.
# Board #61 is completed with solution = 15600.
# Board #62 is completed with solution = 13700.
# Board #64 is completed with solution = 24300.
# Board #67 is completed with solution = 17400.
# Board #68 is completed with solution = 20200.
# Board #70 is completed with solution = 15250.
# Board #71 is completed with solution = 22750.
# Board #73 is completed with solution = 23450.
# Board #76 is completed with solution = 14900.
# Board #82 is completed with solution = 20050.
# Board #83 is completed with solution = 21000.
# Board #84 is completed with solution = 17300.
# Board #86 is completed with solution = 24700.
# Board #87 is completed with solution = 24050.
# Board #88 is completed with solution = 14850.
# Board #89 is completed with solution = 14200.
# Board #92 is completed with solution = 8250.
# Board #93 is completed with solution = 30100.
# Board #98 is completed with solution = 20300.
# Board #99 is completed with solution = 24850.
# Board #100 is completed with solution = 25300.
# Callout: 58
# Board #1 is completed with solution = 21866.
# Board #4 is completed with solution = 9280.
# Board #6 is completed with solution = 25288.
# Board #7 is completed with solution = 14442.
# Board #9 is completed with solution = 9570.
# Board #11 is completed with solution = 14442.
# Board #12 is completed with solution = 20996.
# Board #13 is completed with solution = 21228.
# Board #14 is completed with solution = 21170.
# Board #15 is completed with solution = 20996.
# Board #17 is completed with solution = 13050.
# Board #21 is completed with solution = 22214.
# Board #22 is completed with solution = 16008.
# Board #23 is completed with solution = 15196.
# Board #24 is completed with solution = 26680.
# Board #25 is completed with solution = 12296.
# Board #27 is completed with solution = 22388.
# Board #28 is completed with solution = 31784.
# Board #30 is completed with solution = 23432.
# Board #31 is completed with solution = 29522.
# Board #32 is completed with solution = 18560.
# Board #33 is completed with solution = 24302.
# Board #34 is completed with solution = 37178.
# Board #36 is completed with solution = 22446.
# Board #43 is completed with solution = 37352.
# Board #46 is completed with solution = 19140.
# Board #48 is completed with solution = 11252.
# Board #50 is completed with solution = 28536.
# Board #51 is completed with solution = 21924.
# Board #52 is completed with solution = 24070.
# Board #54 is completed with solution = 26332.
# Board #55 is completed with solution = 11774.
# Board #57 is completed with solution = 22504.
# Board #59 is completed with solution = 19082.
# Board #60 is completed with solution = 23780.
# Board #61 is completed with solution = 14732.
# Board #62 is completed with solution = 15892.
# Board #63 is completed with solution = 18096.
# Board #64 is completed with solution = 28188.
# Board #67 is completed with solution = 20184.
# Board #68 is completed with solution = 20068.
# Board #70 is completed with solution = 14326.
# Board #71 is completed with solution = 23026.
# Board #73 is completed with solution = 27202.
# Board #76 is completed with solution = 17284.
# Board #82 is completed with solution = 23258.
# Board #83 is completed with solution = 24360.
# Board #84 is completed with solution = 20068.
# Board #86 is completed with solution = 25288.
# Board #87 is completed with solution = 24534.
# Board #88 is completed with solution = 17226.
# Board #89 is completed with solution = 13108.
# Board #92 is completed with solution = 9570.
# Board #93 is completed with solution = 34916.
# Board #98 is completed with solution = 23548.
# Board #99 is completed with solution = 28826.
# Board #100 is completed with solution = 29348.
# Callout: 34
# Board #1 is completed with solution = 12818.
# Board #4 is completed with solution = 5440.
# Board #5 is completed with solution = 14348.
# Board #6 is completed with solution = 14824.
# Board #7 is completed with solution = 8466.
# Board #9 is completed with solution = 4454.
# Board #11 is completed with solution = 8466.
# Board #12 is completed with solution = 12308.
# Board #13 is completed with solution = 12444.
# Board #14 is completed with solution = 12410.
# Board #15 is completed with solution = 12308.
# Board #17 is completed with solution = 7650.
# Board #21 is completed with solution = 11866.
# Board #22 is completed with solution = 8228.
# Board #23 is completed with solution = 7752.
# Board #24 is completed with solution = 14484.
# Board #25 is completed with solution = 7208.
# Board #27 is completed with solution = 13124.
# Board #28 is completed with solution = 18632.
# Board #30 is completed with solution = 13736.
# Board #31 is completed with solution = 16150.
# Board #32 is completed with solution = 10880.
# Board #33 is completed with solution = 14246.
# Board #34 is completed with solution = 20638.
# Board #36 is completed with solution = 13158.
# Board #43 is completed with solution = 21896.
# Board #46 is completed with solution = 10064.
# Board #48 is completed with solution = 6596.
# Board #50 is completed with solution = 16728.
# Board #51 is completed with solution = 12852.
# Board #52 is completed with solution = 14110.
# Board #54 is completed with solution = 15436.
# Board #55 is completed with solution = 5746.
# Board #57 is completed with solution = 13192.
# Board #59 is completed with solution = 11186.
# Board #60 is completed with solution = 13940.
# Board #61 is completed with solution = 8636.
# Board #62 is completed with solution = 8160.
# Board #63 is completed with solution = 10608.
# Board #64 is completed with solution = 16524.
# Board #66 is completed with solution = 16626.
# Board #67 is completed with solution = 11832.
# Board #68 is completed with solution = 11764.
# Board #70 is completed with solution = 7242.
# Board #71 is completed with solution = 13498.
# Board #73 is completed with solution = 15946.
# Board #76 is completed with solution = 10132.
# Board #82 is completed with solution = 13634.
# Board #83 is completed with solution = 14280.
# Board #84 is completed with solution = 11764.
# Board #86 is completed with solution = 14824.
# Board #87 is completed with solution = 13226.
# Board #88 is completed with solution = 10098.
# Board #89 is completed with solution = 7684.
# Board #92 is completed with solution = 5610.
# Board #93 is completed with solution = 20468.
# Board #96 is completed with solution = 21488.
# Board #98 is completed with solution = 12648.
# Board #99 is completed with solution = 16898.
# Board #100 is completed with solution = 17204.
# Callout: 27
# Board #1 is completed with solution = 9450.
# Board #4 is completed with solution = 4320.
# Board #5 is completed with solution = 11394.
# Board #6 is completed with solution = 11772.
# Board #7 is completed with solution = 6723.
# Board #9 is completed with solution = 3537.
# Board #11 is completed with solution = 5994.
# Board #12 is completed with solution = 9774.
# Board #13 is completed with solution = 9882.
# Board #14 is completed with solution = 9855.
# Board #15 is completed with solution = 9045.
# Board #17 is completed with solution = 6075.
# Board #21 is completed with solution = 9423.
# Board #22 is completed with solution = 6534.
# Board #23 is completed with solution = 6156.
# Board #24 is completed with solution = 11502.
# Board #25 is completed with solution = 5724.
# Board #27 is completed with solution = 9693.
# Board #28 is completed with solution = 14796.
# Board #30 is completed with solution = 10908.
# Board #31 is completed with solution = 12825.
# Board #32 is completed with solution = 8640.
# Board #33 is completed with solution = 11313.
# Board #34 is completed with solution = 16389.
# Board #36 is completed with solution = 10449.
# Board #38 is completed with solution = 8748.
# Board #43 is completed with solution = 16659.
# Board #46 is completed with solution = 7992.
# Board #48 is completed with solution = 5238.
# Board #50 is completed with solution = 12555.
# Board #51 is completed with solution = 10206.
# Board #52 is completed with solution = 11205.
# Board #53 is completed with solution = 11016.
# Board #54 is completed with solution = 12258.
# Board #55 is completed with solution = 4563.
# Board #57 is completed with solution = 10476.
# Board #59 is completed with solution = 8883.
# Board #60 is completed with solution = 10341.
# Board #61 is completed with solution = 6858.
# Board #62 is completed with solution = 6480.
# Board #63 is completed with solution = 8424.
# Board #64 is completed with solution = 13122.
# Board #66 is completed with solution = 13203.
# Board #67 is completed with solution = 8667.
# Board #68 is completed with solution = 9342.
# Board #70 is completed with solution = 5022.
# Board #71 is completed with solution = 10719.
# Board #73 is completed with solution = 12663.
# Board #75 is completed with solution = 10827.
# Board #76 is completed with solution = 8046.
# Board #82 is completed with solution = 10827.
# Board #83 is completed with solution = 11340.
# Board #84 is completed with solution = 8613.
# Board #85 is completed with solution = 12636.
# Board #86 is completed with solution = 11043.
# Board #87 is completed with solution = 10503.
# Board #88 is completed with solution = 8019.
# Board #89 is completed with solution = 6102.
# Board #92 is completed with solution = 4455.
# Board #93 is completed with solution = 16254.
# Board #96 is completed with solution = 17064.
# Board #98 is completed with solution = 9315.
# Board #99 is completed with solution = 12690.
# Board #100 is completed with solution = 13662.
# Callout: 43
# Board #1 is completed with solution = 15050.
# Board #4 is completed with solution = 6880.
# Board #5 is completed with solution = 16297.
# Board #6 is completed with solution = 18748.
# Board #7 is completed with solution = 10707.
# Board #9 is completed with solution = 5633.
# Board #11 is completed with solution = 9546.
# Board #12 is completed with solution = 15566.
# Board #13 is completed with solution = 15738.
# Board #14 is completed with solution = 13846.
# Board #15 is completed with solution = 14405.
# Board #17 is completed with solution = 9675.
# Board #21 is completed with solution = 15007.
# Board #22 is completed with solution = 10406.
# Board #23 is completed with solution = 9804.
# Board #24 is completed with solution = 18318.
# Board #25 is completed with solution = 9116.
# Board #27 is completed with solution = 13588.
# Board #28 is completed with solution = 21715.
# Board #30 is completed with solution = 17372.
# Board #31 is completed with solution = 20425.
# Board #32 is completed with solution = 13760.
# Board #33 is completed with solution = 18017.
# Board #34 is completed with solution = 26101.
# Board #36 is completed with solution = 16641.
# Board #38 is completed with solution = 13932.
# Board #43 is completed with solution = 26531.
# Board #45 is completed with solution = 14534.
# Board #46 is completed with solution = 12728.
# Board #48 is completed with solution = 8342.
# Board #49 is completed with solution = 6536.
# Board #50 is completed with solution = 18146.
# Board #51 is completed with solution = 14405.
# Board #52 is completed with solution = 17845.
# Board #53 is completed with solution = 15695.
# Board #54 is completed with solution = 19522.
# Board #55 is completed with solution = 7267.
# Board #57 is completed with solution = 16684.
# Board #59 is completed with solution = 12298.
# Board #60 is completed with solution = 16469.
# Board #61 is completed with solution = 10922.
# Board #62 is completed with solution = 10320.
# Board #63 is completed with solution = 11567.
# Board #64 is completed with solution = 20898.
# Board #66 is completed with solution = 21027.
# Board #67 is completed with solution = 11954.
# Board #68 is completed with solution = 14878.
# Board #70 is completed with solution = 7998.
# Board #71 is completed with solution = 15222.
# Board #73 is completed with solution = 20167.
# Board #75 is completed with solution = 17243.
# Board #76 is completed with solution = 12814.
# Board #82 is completed with solution = 17243.
# Board #83 is completed with solution = 18060.
# Board #84 is completed with solution = 13717.
# Board #85 is completed with solution = 20124.
# Board #86 is completed with solution = 17587.
# Board #87 is completed with solution = 14878.
# Board #88 is completed with solution = 10922.
# Board #89 is completed with solution = 9718.
# Board #90 is completed with solution = 18662.
# Board #92 is completed with solution = 7095.
# Board #93 is completed with solution = 25886.
# Board #96 is completed with solution = 27176.
# Board #98 is completed with solution = 14835.
# Board #99 is completed with solution = 20210.
# Board #100 is completed with solution = 21758.
# Callout: 30
# Board #1 is completed with solution = 10500.
# Board #4 is completed with solution = 3900.
# Board #5 is completed with solution = 10470.
# Board #6 is completed with solution = 13080.
# Board #7 is completed with solution = 7470.
# Board #9 is completed with solution = 3930.
# Board #11 is completed with solution = 6660.
# Board #12 is completed with solution = 10860.
# Board #13 is completed with solution = 10080.
# Board #14 is completed with solution = 9660.
# Board #15 is completed with solution = 10050.
# Board #17 is completed with solution = 6750.
# Board #21 is completed with solution = 9570.
# Board #22 is completed with solution = 7260.
# Board #23 is completed with solution = 6840.
# Board #24 is completed with solution = 11880.
# Board #25 is completed with solution = 6360.
# Board #27 is completed with solution = 9480.
# Board #28 is completed with solution = 15150.
# Board #30 is completed with solution = 12120.
# Board #31 is completed with solution = 14250.
# Board #32 is completed with solution = 9600.
# Board #33 is completed with solution = 12570.
# Board #34 is completed with solution = 18210.
# Board #36 is completed with solution = 11610.
# Board #37 is completed with solution = 11850.
# Board #38 is completed with solution = 9720.
# Board #43 is completed with solution = 18510.
# Board #45 is completed with solution = 10140.
# Board #46 is completed with solution = 8880.
# Board #48 is completed with solution = 5820.
# Board #49 is completed with solution = 3660.
# Board #50 is completed with solution = 12660.
# Board #51 is completed with solution = 10050.
# ...
# Board #27 is completed with solution = 139.
# Board #28 is completed with solution = 0.
# Board #29 is completed with solution = 0.
# Board #30 is completed with solution = 0.
# Board #31 is completed with solution = 139.
# Board #32 is completed with solution = 0.
# Board #33 is completed with solution = 130.
# Board #34 is completed with solution = 0.
# Board #35 is completed with solution = 54.
# Board #36 is completed with solution = 130.
# Board #37 is completed with solution = 0.
# Board #38 is completed with solution = 0.
# Board #39 is completed with solution = 85.
# Board #40 is completed with solution = 45.
# Board #41 is completed with solution = 85.
# Board #42 is completed with solution = 0.
# Board #43 is completed with solution = 184.
# Board #44 is completed with solution = 45.
# Board #45 is completed with solution = 85.
# Board #46 is completed with solution = 0.
# Board #47 is completed with solution = 0.
# Board #48 is completed with solution = 0.
# Board #49 is completed with solution = 0.
# Board #50 is completed with solution = 0.
# Board #51 is completed with solution = 130.
# Board #52 is completed with solution = 99.
# Board #53 is completed with solution = 0.
# Board #54 is completed with solution = 85.
# Board #55 is completed with solution = 99.
# Board #56 is completed with solution = 0.
# Board #57 is completed with solution = 99.
# Board #58 is completed with solution = 45.
# Board #59 is completed with solution = 54.
# Board #60 is completed with solution = 0.
# Board #61 is completed with solution = 0.
# Board #62 is completed with solution = 54.
# Board #63 is completed with solution = 54.
# Board #64 is completed with solution = 130.
# Board #65 is completed with solution = 139.
# Board #66 is completed with solution = 139.
# Board #67 is completed with solution = 0.
# Board #68 is completed with solution = 0.
# Board #69 is completed with solution = 45.
# Board #70 is completed with solution = 0.
# Board #71 is completed with solution = 45.
# Board #72 is completed with solution = 54.
# Board #73 is completed with solution = 0.
# Board #74 is completed with solution = 85.
# Board #75 is completed with solution = 85.
# Board #76 is completed with solution = 0.
# Board #77 is completed with solution = 54.
# Board #78 is completed with solution = 139.
# Board #79 is completed with solution = 54.
# Board #80 is completed with solution = 85.
# Board #81 is completed with solution = 0.
# Board #82 is completed with solution = 85.
# Board #83 is completed with solution = 99.
# Board #84 is completed with solution = 54.
# Board #85 is completed with solution = 139.
# Board #86 is completed with solution = 45.
# Board #87 is completed with solution = 0.
# Board #88 is completed with solution = 45.
# Board #89 is completed with solution = 0.
# Board #90 is completed with solution = 0.
# Board #91 is completed with solution = 85.
# Board #92 is completed with solution = 45.
# Board #93 is completed with solution = 99.
# Board #94 is completed with solution = 0.
# Board #95 is completed with solution = 45.
# Board #96 is completed with solution = 0.
# Board #97 is completed with solution = 45.
# Board #98 is completed with solution = 45.
# Board #99 is completed with solution = 99.
# Board #100 is completed with solution = 0.
# Callout: 45
# Board #1 is completed with solution = 0.
# Board #2 is completed with solution = 0.
# Board #3 is completed with solution = 0.
# Board #4 is completed with solution = 0.
# Board #5 is completed with solution = 3825.
# Board #6 is completed with solution = 3825.
# Board #7 is completed with solution = 0.
# Board #8 is completed with solution = 6255.
# Board #9 is completed with solution = 0.
# Board #10 is completed with solution = 0.
# Board #11 is completed with solution = 2430.
# Board #12 is completed with solution = 3825.
# Board #13 is completed with solution = 0.
# Board #14 is completed with solution = 0.
# Board #15 is completed with solution = 3825.
# Board #16 is completed with solution = 3825.
# Board #17 is completed with solution = 0.
# Board #18 is completed with solution = 3825.
# Board #19 is completed with solution = 0.
# Board #20 is completed with solution = 0.
# Board #21 is completed with solution = 0.
# Board #22 is completed with solution = 0.
# Board #23 is completed with solution = 0.
# Board #24 is completed with solution = 0.
# Board #25 is completed with solution = 0.
# Board #26 is completed with solution = 0.
# Board #27 is completed with solution = 6255.
# Board #28 is completed with solution = 0.
# Board #29 is completed with solution = 0.
# Board #30 is completed with solution = 0.
# Board #31 is completed with solution = 6255.
# Board #32 is completed with solution = 0.
# Board #33 is completed with solution = 3825.
# Board #34 is completed with solution = 0.
# Board #35 is completed with solution = 2430.
# Board #36 is completed with solution = 3825.
# Board #37 is completed with solution = 0.
# Board #38 is completed with solution = 0.
# Board #39 is completed with solution = 3825.
# Board #40 is completed with solution = 0.
# Board #41 is completed with solution = 3825.
# Board #42 is completed with solution = 0.
# Board #43 is completed with solution = 6255.
# Board #44 is completed with solution = 0.
# Board #45 is completed with solution = 3825.
# Board #46 is completed with solution = 0.
# Board #47 is completed with solution = 0.
# Board #48 is completed with solution = 0.
# Board #49 is completed with solution = 0.
# Board #50 is completed with solution = 0.
# Board #51 is completed with solution = 3825.
# Board #52 is completed with solution = 2430.
# Board #53 is completed with solution = 0.
# Board #54 is completed with solution = 3825.
# Board #55 is completed with solution = 2430.
# Board #56 is completed with solution = 0.
# Board #57 is completed with solution = 2430.
# Board #58 is completed with solution = 0.
# Board #59 is completed with solution = 2430.
# Board #60 is completed with solution = 0.
# Board #61 is completed with solution = 0.
# Board #62 is completed with solution = 2430.
# Board #63 is completed with solution = 2430.
# Board #64 is completed with solution = 3825.
# Board #65 is completed with solution = 6255.
# Board #66 is completed with solution = 6255.
# Board #67 is completed with solution = 0.
# Board #68 is completed with solution = 0.
# Board #69 is completed with solution = 0.
# Board #70 is completed with solution = 0.
# Board #71 is completed with solution = 0.
# Board #72 is completed with solution = 2430.
# Board #73 is completed with solution = 0.
# Board #74 is completed with solution = 3825.
# Board #75 is completed with solution = 3825.
# Board #76 is completed with solution = 0.
# Board #77 is completed with solution = 2430.
# Board #78 is completed with solution = 6255.
# Board #79 is completed with solution = 2430.
# Board #80 is completed with solution = 3825.
# Board #81 is completed with solution = 0.
# Board #82 is completed with solution = 3825.
# Board #83 is completed with solution = 2430.
# Board #84 is completed with solution = 2430.
# Board #85 is completed with solution = 6255.
# Board #86 is completed with solution = 0.
# Board #87 is completed with solution = 0.
# Board #88 is completed with solution = 0.
# Board #89 is completed with solution = 0.
# Board #90 is completed with solution = 0.
# Board #91 is completed with solution = 3825.
# Board #92 is completed with solution = 0.
# Board #93 is completed with solution = 2430.
# Board #94 is completed with solution = 0.
# Board #95 is completed with solution = 0.
# Board #96 is completed with solution = 0.
# Board #97 is completed with solution = 0.
# Board #98 is completed with solution = 0.
# Board #99 is completed with solution = 2430.
# Board #100 is completed with solution = 0.
# Callout: 54
# Board #1 is completed with solution = 0.
# Board #2 is completed with solution = 0.
# Board #3 is completed with solution = 0.
# Board #4 is completed with solution = 0.
# Board #5 is completed with solution = 4590.
# Board #6 is completed with solution = 4590.
# Board #7 is completed with solution = 0.
# Board #8 is completed with solution = 4590.
# Board #9 is completed with solution = 0.
# Board #10 is completed with solution = 0.
# Board #11 is completed with solution = 0.
# Board #12 is completed with solution = 4590.
# Board #13 is completed with solution = 0.
# Board #14 is completed with solution = 0.
# Board #15 is completed with solution = 4590.
# Board #16 is completed with solution = 4590.
# Board #17 is completed with solution = 0.
# Board #18 is completed with solution = 4590.
# Board #19 is completed with solution = 0.
# Board #20 is completed with solution = 0.
# Board #21 is completed with solution = 0.
# Board #22 is completed with solution = 0.
# Board #23 is completed with solution = 0.
# Board #24 is completed with solution = 0.
# Board #25 is completed with solution = 0.
# Board #26 is completed with solution = 0.
# Board #27 is completed with solution = 4590.
# Board #28 is completed with solution = 0.
# Board #29 is completed with solution = 0.
# Board #30 is completed with solution = 0.
# Board #31 is completed with solution = 4590.
# Board #32 is completed with solution = 0.
# Board #33 is completed with solution = 4590.
# Board #34 is completed with solution = 0.
# Board #35 is completed with solution = 0.
# Board #36 is completed with solution = 4590.
# Board #37 is completed with solution = 0.
# Board #38 is completed with solution = 0.
# Board #39 is completed with solution = 4590.
# Board #40 is completed with solution = 0.
# Board #41 is completed with solution = 4590.
# Board #42 is completed with solution = 0.
# Board #43 is completed with solution = 4590.
# Board #44 is completed with solution = 0.
# Board #45 is completed with solution = 4590.
# Board #46 is completed with solution = 0.
# Board #47 is completed with solution = 0.
# Board #48 is completed with solution = 0.
# Board #49 is completed with solution = 0.
# Board #50 is completed with solution = 0.
# Board #51 is completed with solution = 4590.
# Board #52 is completed with solution = 0.
# Board #53 is completed with solution = 0.
# Board #54 is completed with solution = 4590.
# Board #55 is completed with solution = 0.
# Board #56 is completed with solution = 0.
# Board #57 is completed with solution = 0.
# Board #58 is completed with solution = 0.
# Board #59 is completed with solution = 0.
# Board #60 is completed with solution = 0.
# Board #61 is completed with solution = 0.
# Board #62 is completed with solution = 0.
# Board #63 is completed with solution = 0.
# Board #64 is completed with solution = 4590.
# Board #65 is completed with solution = 4590.
# Board #66 is completed with solution = 4590.
# Board #67 is completed with solution = 0.
# Board #68 is completed with solution = 0.
# Board #69 is completed with solution = 0.
# Board #70 is completed with solution = 0.
# Board #71 is completed with solution = 0.
# Board #72 is completed with solution = 0.
# Board #73 is completed with solution = 0.
# Board #74 is completed with solution = 4590.
# Board #75 is completed with solution = 4590.
# Board #76 is completed with solution = 0.
# Board #77 is completed with solution = 0.
# Board #78 is completed with solution = 4590.
# Board #79 is completed with solution = 0.
# Board #80 is completed with solution = 4590.
# Board #81 is completed with solution = 0.
# Board #82 is completed with solution = 4590.
# Board #83 is completed with solution = 0.
# Board #84 is completed with solution = 0.
# Board #85 is completed with solution = 4590.
# Board #86 is completed with solution = 0.
# Board #87 is completed with solution = 0.
# Board #88 is completed with solution = 0.
# Board #89 is completed with solution = 0.
# Board #90 is completed with solution = 0.
# Board #91 is completed with solution = 4590.
# Board #92 is completed with solution = 0.
# Board #93 is completed with solution = 0.
# Board #94 is completed with solution = 0.
# Board #95 is completed with solution = 0.
# Board #96 is completed with solution = 0.
# Board #97 is completed with solution = 0.
# Board #98 is completed with solution = 0.
# Board #99 is completed with solution = 0.
# Board #100 is completed with solution = 0.
# Callout: 85
# Board #1 is completed with solution = 0.
# Board #2 is completed with solution = 0.
# Board #3 is completed with solution = 0.
# Board #4 is completed with solution = 0.
# Board #5 is completed with solution = 0.
# Board #6 is completed with solution = 0.
# Board #7 is completed with solution = 0.
# Board #8 is completed with solution = 0.
# Board #9 is completed with solution = 0.
# Board #10 is completed with solution = 0.
# Board #11 is completed with solution = 0.
# Board #12 is completed with solution = 0.
# Board #13 is completed with solution = 0.
# Board #14 is completed with solution = 0.
# Board #15 is completed with solution = 0.
# Board #16 is completed with solution = 0.
# Board #17 is completed with solution = 0.
# Board #18 is completed with solution = 0.
# Board #19 is completed with solution = 0.
# Board #20 is completed with solution = 0.
# Board #21 is completed with solution = 0.
# Board #22 is completed with solution = 0.
# Board #23 is completed with solution = 0.
# Board #24 is completed with solution = 0.
# Board #25 is completed with solution = 0.
# Board #26 is completed with solution = 0.
# Board #27 is completed with solution = 0.
# Board #28 is completed with solution = 0.
# Board #29 is completed with solution = 0.
# Board #30 is completed with solution = 0.
# Board #31 is completed with solution = 0.
# Board #32 is completed with solution = 0.
# Board #33 is completed with solution = 0.
# Board #34 is completed with solution = 0.
# Board #35 is completed with solution = 0.
# Board #36 is completed with solution = 0.
# Board #37 is completed with solution = 0.
# Board #38 is completed with solution = 0.
# Board #39 is completed with solution = 0.
# Board #40 is completed with solution = 0.
# Board #41 is completed with solution = 0.
# Board #42 is completed with solution = 0.
# Board #43 is completed with solution = 0.
# Board #44 is completed with solution = 0.
# Board #45 is completed with solution = 0.
# Board #46 is completed with solution = 0.
# Board #47 is completed with solution = 0.
# Board #48 is completed with solution = 0.
# Board #49 is completed with solution = 0.
# Board #50 is completed with solution = 0.
# Board #51 is completed with solution = 0.
# Board #52 is completed with solution = 0.
# Board #53 is completed with solution = 0.
# Board #54 is completed with solution = 0.
# Board #55 is completed with solution = 0.
# Board #56 is completed with solution = 0.
# Board #57 is completed with solution = 0.
# Board #58 is completed with solution = 0.
# Board #59 is completed with solution = 0.
# Board #60 is completed with solution = 0.
# Board #61 is completed with solution = 0.
# Board #62 is completed with solution = 0.
# Board #63 is completed with solution = 0.
# Board #64 is completed with solution = 0.
# Board #65 is completed with solution = 0.
# Board #66 is completed with solution = 0.
# Board #67 is completed with solution = 0.
# Board #68 is completed with solution = 0.
# Board #69 is completed with solution = 0.
# Board #70 is completed with solution = 0.
# Board #71 is completed with solution = 0.
# Board #72 is completed with solution = 0.
# Board #73 is completed with solution = 0.
# Board #74 is completed with solution = 0.
# Board #75 is completed with solution = 0.
# Board #76 is completed with solution = 0.
# Board #77 is completed with solution = 0.
# Board #78 is completed with solution = 0.
# Board #79 is completed with solution = 0.
# Board #80 is completed with solution = 0.
# Board #81 is completed with solution = 0.
# Board #82 is completed with solution = 0.
# Board #83 is completed with solution = 0.
# Board #84 is completed with solution = 0.
# Board #85 is completed with solution = 0.
# Board #86 is completed with solution = 0.
# Board #87 is completed with solution = 0.
# Board #88 is completed with solution = 0.
# Board #89 is completed with solution = 0.
# Board #90 is completed with solution = 0.
# Board #91 is completed with solution = 0.
# Board #92 is completed with solution = 0.
# Board #93 is completed with solution = 0.
# Board #94 is completed with solution = 0.
# Board #95 is completed with solution = 0.
# Board #96 is completed with solution = 0.
# Board #97 is completed with solution = 0.
# Board #98 is completed with solution = 0.
# Board #99 is completed with solution = 0.
# Board #100 is completed with solution = 0.

# %%
# The final entry of winners (which can be indexed using -1) is the "final winner".
# To find the solution, find the first instance of winners[-1] in the printout in the previous cell

winners[-1]
# Out:
# 65
